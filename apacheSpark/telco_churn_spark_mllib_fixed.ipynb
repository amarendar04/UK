# %% [markdown]
# # Telco Churn - Fixed: Stratified split, SMOTE, consistent features, F1, SHAP, graceful shutdown
#
# This notebook is a corrected version addressing class imbalance, stratified splitting, consistent feature usage across models, proper evaluation (F1), and model interpretability with SHAP (via a sklearn surrogate).

# %%
# Install optional dependencies used for balancing and interpretability (runs in notebook)
import sys
import subprocess
def pip_install(packages):
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--quiet'] + packages)
: 
,
: {
: 

: [
,
# Out:
#   Cell In[1], line 6
#     :
#     ^
# SyntaxError: invalid syntax

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import DoubleType, IntegerType
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.functions import vector_to_array
import os

,
